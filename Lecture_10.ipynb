# %% [markdown]
# ## Lecture 9 Pandas and For loops
# - Sahil Raj B-31

# %%
# Setup
import pandas as pd

# %%
div_scores_dictionary = {"student_name": ["Jay", "Aaryan", "Sahil","Riya","Shubh"],
                         "math_scores": [20,56,76,78,90],
                         "chemistry_scores": [32,36,78,23,100],
                         "information_technology_scores": [34,6,88,100,45],
                         "physics_scores": [6,88,48,90,25]
                         }
div_emails_dictionary = {"student_name": ["Jay", "Aaryan", "Sahil","Riya","Shubh", "Abdul"],
                           "student_email": ["Jay@gmail.com", "Aaryan@gmail.com", "Sahil@gmail.com","Riya@gmail.com","Shubh@gmail.com", "Abdual@gmail.com"]
                         }

# %%
def get_scores_df(dictionary):
    scores_df = pd.DataFrame(dictionary)
    scores_df["total_score"] = scores_df["math_scores"] + scores_df["chemistry_scores"] + scores_df["information_technology_scores"]+ scores_df["physics_scores"]
    scores_df["average_scores"] = scores_df["total_score"]/4
    return scores_df

# %%
get_scores_df(div_scores_dictionary)
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0          Jay           20                32                             34
# 1       Aaryan           56                36                              6
# 2        Sahil           76                78                             88
# 3         Riya           78                23                            100
# 4        Shubh           90               100                             45
#
#    physics_scores  total_score  average_scores
# 0               6           92           23.00
# 1              88          186           46.50
# 2              48          290           72.50
# 3              90          291           72.75
# 4              25          260           65.00

# %%
report_database = [
   {
      "class":10,
      "division":"A",
      "teacher":"Zoshua Colah",
      "scores":{
         "student_name":[
            "Jay",
            "Aaryan",
            "Sahil",
            "Riya",
            "Shubh"
         ],
         "math_scores":[
            20,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            32,
            36,
            78,
            23,
            100
         ],
         "information_technology_scores":[
            34,
            6,
            88,
            100,
            45
         ],
         "physics_scores":[
            6,
            88,
            48,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Jay",
            "Aaryan",
            "Sahil",
            "Riya",
            "Shubh",
            "Abdul"
         ],
         "student_email":[
            "Jay@gmail.com",
            "Aaryan@gmail.com",
            "Sahil@gmail.com",
            "Riya@gmail.com",
            "Shubh@gmail.com",
            "Abdual@gmail.com"
         ]
      }
   },
   {
      "class":10,
      "division":"B",
      "teacher":"Aayushi Shah",
      "scores":{
         "student_name":[
            "Jai",
            "Aryan",
            "Firoz",
            "Steve",
            "Rhea"
         ],
         "math_scores":[
            32,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            32,
            56,
            75,
            23,
            10
         ],
         "information_technology_scores":[
            34,
            6,
            48,
            100,
            45
         ],
         "physics_scores":[
            6,
            88,
            58,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Jai",
            "Aryan",
            "Firoz",
            "Steve",
            "Rhea"
         ],
         "student_email":[
            "Jai@gmail.com",
            "Aryan@gmail.com",
            "Firoz@gmail.com",
            "Steve@gmail.com",
            "Rhea@gmail.com"
         ]
      }
   },
   {
      "class":10,
      "division":"C",
      "teacher":"Rahul Joy",
      "scores":{
         "student_name":[
            "Kareena",
            "Alia",
            "Priyanka",
            "Shahrukh",
            "Salman"
         ],
         "math_scores":[
            22,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            30,
            56,
            78,
            23,
            100
         ],
         "information_technology_scores":[
            34,
            6,
            98,
            100,
            40
         ],
         "physics_scores":[
            60,
            88,
            58,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Kareena",
            "Alia",
            "Priyanka",
            "Shahrukh",
            "Salman"
         ],
         "student_email":[
            "Kareena@gmail.com",
            "Alia@gmail.com",
            "Priyanka@gmail.com",
            "Shahrukh@gmail.com",
            "Salman@gmail.com"
         ]
      }
   }
]

# %%
report_database
# Out:
# [{'class': 10,
#   'division': 'A',
#   'teacher': 'Zoshua Colah',
#   'scores': {'student_name': ['Jay', 'Aaryan', 'Sahil', 'Riya', 'Shubh'],
#    'math_scores': [20, 56, 76, 78, 90],
#    'chemistry_scores': [32, 36, 78, 23, 100],
#    'information_technology_scores': [34, 6, 88, 100, 45],
#    'physics_scores': [6, 88, 48, 90, 25]},
#   'emails': {'student_name': ['Jay',
#     'Aaryan',
#     'Sahil',
#     'Riya',
#     'Shubh',
#     'Abdul'],
#    'student_email': ['Jay@gmail.com',
#     'Aaryan@gmail.com',
#     'Sahil@gmail.com',
#     'Riya@gmail.com',
#     'Shubh@gmail.com',
#     'Abdual@gmail.com']}},
#  {'class': 10,
#   'division': 'B',
#   'teacher': 'Aayushi Shah',
#   'scores': {'student_name': ['Jai', 'Aryan', 'Firoz', 'Steve', 'Rhea'],
#    'math_scores': [32, 56, 76, 78, 90],
#    'chemistry_scores': [32, 56, 75, 23, 10],
#    'information_technology_scores': [34, 6, 48, 100, 45],
#    'physics_scores': [6, 88, 58, 90, 25]},
# ...

# %% [markdown]
# # List traverser function

# %%
def get_report_df(report_list):
    
    # save an empty mega report card data frame 
    mega_report_df=pd.DataFrame()
    #For loop
    #for each class Dictionary in the list :
   ########################################################################################
    for division in report_list:
    
    # make scores df 
        scores_df=pd.DataFrame(division["scores"])
    # make emails df
        
        emails_df=pd.DataFrame(division["emails"])
        emails_df["student_email"] = emails_df["student_email"].str.lower()
    
    # merge the scores df with emails df
        scores_emails_df=pd.merge(scores_df,emails_df, how = "left" , on =["student_name"])
    
    # add the class column
        scores_emails_df["class"]=division["class"]
    
    # add the division column
        scores_emails_df["division"]=division["division"]
    
    # add the teacher column 
        scores_emails_df["teacher"]=division["teacher"]
    
    # add (concat)  it to a mega report card dataframe
        mega_report_df=pd.concat([mega_report_df,scores_emails_df],ignore_index = True)
   ###########################################################################################
   # add total score
    mega_report_df["total_score"] = mega_report_df["math_scores"] +mega_report_df["chemistry_scores"] +mega_report_df["information_technology_scores"]+mega_report_df["physics_scores"]
   # add average scores
    mega_report_df["average_scores"] = mega_report_df["total_score"]/4
    
    # add pass fail column
    mega_report_df.loc[mega_report_df["average_scores"]>=35,"status"]= "Pass"
    mega_report_df.loc[mega_report_df["average_scores"]<35,"status"]= "Fail"
    
    # add character Grades
    mega_report_df.loc[(mega_report_df["average_scores"]>=90),"Grade"] = "A"
    mega_report_df.loc[(mega_report_df["average_scores"]>=70) & (mega_report_df["average_scores"]<90),"Grade"] = "B"
    mega_report_df.loc[(mega_report_df["average_scores"]>=50) & (mega_report_df["average_scores"]<70),"Grade"] = "C"
    mega_report_df.loc[(mega_report_df["average_scores"]>=35) & (mega_report_df["average_scores"]<50),"Grade"] = "D"
    mega_report_df.loc[(mega_report_df["average_scores"]<35),"Grade"] = "F"
    
    #return the mega report card data frame 
    return mega_report_df

# %%
main_report=get_report_df(report_database)
main_report
# Out:
#    student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0           Jay           20                32                             34
# 1        Aaryan           56                36                              6
# 2         Sahil           76                78                             88
# 3          Riya           78                23                            100
# 4         Shubh           90               100                             45
# 5           Jai           32                32                             34
# 6         Aryan           56                56                              6
# 7         Firoz           76                75                             48
# 8         Steve           78                23                            100
# 9          Rhea           90                10                             45
# 10      Kareena           22                30                             34
# ...

# %% [markdown]
# # we want to know how many student pass and fail in each devision ?

# %%
pass_fail_df = main_report.groupby(["division","status"]).agg(total_students = ("status","count"))
pass_fail_df
# Out:
#                  total_students
# division status
# A        Fail                 1
#          Pass                 4
# B        Fail                 1
#          Pass                 4
# C        Pass                 5

# %% [markdown]
# # we want to know what is the mean total score by division?

# %%
mean_total_score_df=main_report.groupby(["division"]).agg(mean_total_score = ("total_score","mean"))
mean_total_score_df
# Out:
#           mean_total_score
# division
# A                    223.8
# B                    205.6
# C                    241.6

# %% [markdown]
# # we want to know what is the lowest physics score by division?

# %%
low_physics_score_df=main_report.groupby(["division"]).agg(min_physics_score = ("physics_scores","min"))
low_physics_score_df
# Out:
#           min_physics_score
# division
# A                         6
# B                         6
# C                        25

# %% [markdown]
# # we want to know what is the highest physics score by division?

# %%
max_physics_score_df=main_report.groupby(["division"]).agg(max_physics_score = ("physics_scores","max"))
max_physics_score_df
# Out:
#           max_physics_score
# division
# A                        90
# B                        90
# C                        90

# %% [markdown]
# # we want to know what

# %%
total_student_df=main_report.groupby(["Grade","division"]).agg(total_student= ("Grade","count"))
total_student_df
# Out:
#                 total_student
# Grade division
# B     A                     2
#       B                     1
#       C                     2
# C     A                     1
#       B                     2
#       C                     2
# D     A                     1
#       B                     1
#       C                     1
# F     A                     1
#       B                     1

# %% [markdown]
# # We want to know the average math, physics,chemistry score by division?

# %%
pcm_avg_df = main_report.groupby(["division"]).agg(avg_math_score=("math_scores","mean"),
                                                   avg_chem_scores=("chemistry_scores","mean"),
                                                   avg_physics_scores=("physics_scores","mean"))
pcm_avg_df
# Out:
#           avg_math_score  avg_chem_scores  avg_physics_scores
# division
# A                   64.0             53.8                51.4
# B                   66.4             39.2                53.4
# C                   64.4             57.4                64.2

# %% [markdown]
# # we want to see only the students who have total scores above or equal to 250

# %%
top_students_df = main_report.loc[main_report["total_score"]>=250].reset_index()
top_students_df
# Out:
#    index student_name  math_scores  chemistry_scores  \
# 0      2        Sahil           76                78
# 1      3         Riya           78                23
# 2      4        Shubh           90               100
# 3      7        Firoz           76                75
# 4      8        Steve           78                23
# 5     12     Priyanka           76                78
# 6     13     Shahrukh           78                23
# 7     14       Salman           90               100
#
#    information_technology_scores  physics_scores       student_email  class  \
# 0                             88              48     sahil@gmail.com     10
# 1                            100              90      riya@gmail.com     10
# 2                             45              25     shubh@gmail.com     10
# 3                             48              58     firoz@gmail.com     10
# 4                            100              90     steve@gmail.com     10
# ...

# %%
fail_students_df = main_report.loc[main_report["status"]=="Fail"].reset_index()

fail_students_df
# Out:
#    index student_name  math_scores  chemistry_scores  \
# 0      0          Jay           20                32
# 1      5          Jai           32                32
#
#    information_technology_scores  physics_scores  student_email  class  \
# 0                             34               6  jay@gmail.com     10
# 1                             34               6  jai@gmail.com     10
#
#   division       teacher  total_score  average_scores status Grade
# 0        A  Zoshua Colah           92            23.0   Fail     F
# 1        B  Aayushi Shah          104            26.0   Fail     F

# %% [markdown]
# # we want to see students from B division who got more than and equal to 250

# %%
b_250_df=main_report.loc[(main_report["division"]=="B") & (main_report["total_score"]>=250)].reset_index()
b_250_df
# Out:
#    index student_name  math_scores  chemistry_scores  \
# 0      7        Firoz           76                75
# 1      8        Steve           78                23
#
#    information_technology_scores  physics_scores    student_email  class  \
# 0                             48              58  firoz@gmail.com     10
# 1                            100              90  steve@gmail.com     10
#
#   division       teacher  total_score  average_scores status Grade
# 0        B  Aayushi Shah          257           64.25   Pass     C
# 1        B  Aayushi Shah          291           72.75   Pass     B

# %% [markdown]
# # We want to see a report from B or C division"

# %%
b_c_df=main_report.loc[(main_report["division"]=="B") | (main_report["division"]=="C")].reset_index()
b_c_df
# Out:
#    index student_name  math_scores  chemistry_scores  \
# 0      5          Jai           32                32
# 1      6        Aryan           56                56
# 2      7        Firoz           76                75
# 3      8        Steve           78                23
# 4      9         Rhea           90                10
# 5     10      Kareena           22                30
# 6     11         Alia           56                56
# 7     12     Priyanka           76                78
# 8     13     Shahrukh           78                23
# 9     14       Salman           90               100
#
#    information_technology_scores  physics_scores       student_email  class  \
# 0                             34               6       jai@gmail.com     10
# 1                              6              88     aryan@gmail.com     10
# 2                             48              58     firoz@gmail.com     10
# ...

# %%
teacher_challenge_df=main_report.loc[(main_report["teacher"]=="Aayushi Shah") | (main_report["teacher"]=="Zoshua Colah")]
teacher_challenge_df= teacher_challenge_df.groupby(["teacher"]).agg(min_math_score=("math_scores","min"),
                                                   avg_chem_scores=("chemistry_scores","mean"),
                                                   max_physics_scores=("physics_scores","max"))
teacher_challenge_df
# Out:
#               min_math_score  avg_chem_scores  max_physics_scores
# teacher
# Aayushi Shah              32             39.2                  90
# Zoshua Colah              20             53.8                  90

# %%
melted_df=pd.melt(main_report, id_vars=["student_name","division"], value_vars = ["math_scores","physics_scores"],var_name="Subject",value_name="Score")
melted_df
# Out:
#    student_name division         Subject  Score
# 0           Jay        A     math_scores     20
# 1        Aaryan        A     math_scores     56
# 2         Sahil        A     math_scores     76
# 3          Riya        A     math_scores     78
# 4         Shubh        A     math_scores     90
# 5           Jai        B     math_scores     32
# 6         Aryan        B     math_scores     56
# 7         Firoz        B     math_scores     76
# 8         Steve        B     math_scores     78
# 9          Rhea        B     math_scores     90
# 10      Kareena        C     math_scores     22
# 11         Alia        C     math_scores     56
# 12     Priyanka        C     math_scores     76
# 13     Shahrukh        C     math_scores     78
# 14       Salman        C     math_scores     90
# 15          Jay        A  physics_scores      6
# 16       Aaryan        A  physics_scores     88
# 17        Sahil        A  physics_scores     48
# 18         Riya        A  physics_scores     90
# ...
